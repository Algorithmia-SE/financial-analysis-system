# %%
from typing import List, Dict
from typing_extensions import TypedDict
from langgraph.graph import StateGraph, START, END
from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph.message import add_messages
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate
from langchain_community.tools.tavily_search import TavilySearchResults
from dotenv import load_dotenv
import re
import os

# %%
load_dotenv()

# Memory for state checkpointing
memory = MemorySaver()

# ReWOO State Definition
class ReWOOState(TypedDict):
    task: str
    plan_string: str
    steps: List  # List of (Plan description, step_name, tool, tool_input)
    results: Dict[str, str]
    result: str

# Groq LLaMA 3 Model Initialization
llm = ChatGroq(
    model="llama3-8b-8192",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
)

# Prompt Template for planning
planner_prompt_template = """
For the following task, make step-by-step plans to solve the problem. Indicate which external tool to use:
(1) Google(query): For online search.
(2) LLM(instruction): General knowledge reasoning.

Example:
Task: Example math problem
Plan: Analyze the problem using LLM. #E1 = LLM[Analyze math expression]
Plan: Search current economic situation. #E2 = Google[Nigeria economic news 2024]

Describe plans with rich details. Format:
Plan: (your plan description) #E(step_number) = (Tool)[(input)]

Task: {task}
"""

regex_pattern = r"Plan:\s*(.*?)\s*#E(\d+)\s*=\s*(\w+)\s*\[(.*?)\]"

planner_chain = ChatPromptTemplate.from_template(planner_prompt_template) | llm
search_tool = TavilySearchResults(max_results=2)

# Step 1: Planning Node
def planning_node(state: ReWOOState) -> Dict:
    task = state["task"]
    response = planner_chain.invoke({"task": task})
    plan_text = response.content

    matches = re.findall(regex_pattern, plan_text, re.DOTALL)
    steps = [(plan.strip(), f"#E{step}", tool.strip(), tool_input.strip())
             for plan, step, tool, tool_input in matches]

    return {"plan_string": plan_text, "steps": steps, "results": {}}

# Step 2: Tool Execution Node
def get_next_step_index(state: ReWOOState):
    if not state.get("results"):
        return 0
    return len(state["results"])

def tool_execution_node(state: ReWOOState) -> Dict:
    step_idx = get_next_step_index(state)
    if step_idx >= len(state["steps"]):
        return {}

    plan, step_name, tool, tool_input = state["steps"][step_idx]
    results = state.get("results", {})

    # Replace previous evidence variables in the input
    for k, v in results.items():
        tool_input = tool_input.replace(k, v)

    if tool == "Google":
        result = search_tool.invoke({"query": tool_input})
        output = str(result)
    elif tool == "LLM":
        output = llm.invoke(tool_input).content
    else:
        raise ValueError(f"Unsupported tool: {tool}")

    results[step_name] = output
    return {"results": results}

# Step 3: Solving Node
solve_template = """
Solve the following problem based on the Plan and collected Evidence:

{plan_string}

Evidence:
{evidence}

Task: {task}

Provide the final answer directly:
"""

def solve_node(state: ReWOOState) -> Dict:
    evidence = "\n".join([f"{k}: {v}" for k, v in (state["results"] or {}).items()])
    prompt = solve_template.format(
        plan_string=state.get("plan_string", ""),
        evidence=evidence,
        task=state["task"]
    )
    response = llm.invoke(prompt)
    return {"result": response.content}

# Step 4: Routing Logic
def route_next(state: ReWOOState) -> str:
    if len(state.get("results", {})) < len(state.get("steps", [])):
        return "tool"
    return "solve"

# %%
# Graph Construction
graph = StateGraph(ReWOOState)
graph.add_node("plan", planning_node)
graph.add_node("tool", tool_execution_node)
graph.add_node("solve", solve_node)

graph.add_edge("plan", "tool")
graph.add_conditional_edges("tool", route_next)
graph.add_edge("solve", END)
graph.add_edge(START, "plan")

app = graph.compile()

# %%
from IPython.display import Markdown, display

# Compile the graph
app = graph.compile()

# Extract mermaid code (only after compile)
mermaid_code = app.get_graph().draw_mermaid()

# Display the mermaid diagram (renders in Jupyter Notebooks)
display(Markdown(f"```mermaid\n{mermaid_code}\n```"))
# Out:
# ```mermaid
# ---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	plan(plan)
# 	tool(tool)
# 	solve(solve)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> plan;
# 	plan --> tool;
# 	solve --> __end__;
# 	tool -.-> plan;
# 	tool -.-> solve;
# 	tool -.-> __end__;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc
#
# ```

# %%
# Run Example
if __name__ == "__main__":
    task_input = {"task": "Write a movie script about Nigeria and its economic situation"}

    for s in app.stream(task_input):
        print(f"Current State: {s}\n{'-'*60}")

    print("\nFinal Result:")
    print(s.get('result'))
# Out:
# Current State: {'plan': {'plan_string': 'Here\'s a step-by-step plan to solve the problem:\n\n**Plan: Gather information about Nigeria\'s economic situation #E1 = Google[Nigeria economic news 2024]**\n\n* Start by searching online for recent news articles about Nigeria\'s economic situation using Google.\n* Use specific keywords such as "Nigeria economic news 2024" to get relevant results.\n* Read through the search results to get an overview of the current economic situation in Nigeria, including any major challenges or developments.\n* Take note of key points, such as GDP growth rates, inflation rates, and major industries driving the economy.\n\n**Plan: Analyze the economic situation using LLM #E2 = LLM[Analyze economic data]**\n\n* Use a Large Language Model (LLM) to analyze the economic data gathered from the search results.\n* Input the data into the LLM and ask it to identify trends, patterns, and correlations between different economic indicators.\n* Use the LLM\'s reasoning capabilities to identify potential causes and effects of the economic situation in Nigeria.\n* Take note of any insights or observations that the LLM provides about the economic situation.\n\n**Plan: Brainstorm ideas for the movie script #E3 = LLM[Generate movie ideas]**\n\n* Use the LLM to generate ideas for a movie script about Nigeria and its economic situation.\n* Input the economic data and insights gathered from the previous steps into the LLM and ask it to come up with potential storylines, characters, and plot twists.\n* Use the LLM\'s creative capabilities to generate a list of potential movie ideas that incorporate the economic situation in Nigeria.\n\n**Plan: Write the movie script #E4 = [Manual writing]**\n\n* Use the ideas generated by the LLM to write a movie script about Nigeria and its economic situation.\n* Write a compelling story that incorporates the economic data and insights gathered from the previous steps.\n* Use the LLM\'s suggestions as a starting point, but feel free to modify or discard them as needed to create a unique and engaging story.\n\n**Plan: Edit and refine the movie script #E5 = [Manual editing]**\n\n* Review the movie script and make any necessary edits or revisions.\n* Use the LLM to proofread and suggest improvements to the script, if needed.\n* Refine the script to ensure it is engaging, well-written, and accurately reflects the economic situation in Nigeria.\n\nBy following these steps, you should be able to create a movie script that effectively incorporates the economic situation in Nigeria and tells a compelling story.', 'steps': [("Gather information about Nigeria's economic situation", '#E1', 'Google', 'Nigeria economic news 2024'), ('Analyze the economic situation using LLM', '#E2', 'LLM', 'Analyze economic data'), ('Brainstorm ideas for the movie script', '#E3', 'LLM', 'Generate movie ideas')], 'results': {}}}
# ------------------------------------------------------------
# Current State: {'tool': {'results': {'#E1': '[{\'title\': "Nigeria\'s GDP growth accelerates to 3.84% in fourth quarter of 2024", \'url\': \'https://www.youtube.com/watch?v=2Ob9dAXKDhY\', \'content\': "Nigeria\'s GDP growth accelerates to 3.84% in fourth quarter of 2024 In the fourth quarter of 2024, Nigeria\'s economy experienced a notable", \'score\': 0.9119436}, {\'title\': "Nigeria\'s GDP growth accelerates to 3.84% in fourth quarter of 2024", \'url\': \'https://www.africanews.com/2025/02/26/nigerias-gdp-growth-accelerates-to-384-in-fourth-quarter-of-2024/\', \'content\': "Cybercrime crackdown: 306 arrested in Africa-wide operation\\n\\nA restored ancient museum palace showcases treasures from the Islamic world\\n\\nAdvertising\\n\\nBusiness\\n\\nNigeria\'s GDP growth accelerates to 3.84% in fourth quarter of 2
': "Nigeria\'s GDP growth accelerates to 3.84% in fourth quarter of 2024 In the fourth quarter of 2024, Nigeria\'s economy experienced a notable", \'score\': 0.9119436}, {\'title\': "Nigeria\'s GDP growth accelerates to 3.84% in fourth quarter of 2024", \'url\': \'https://www.africanews.com/2025/02/26/nigerias-gdp-growth-accelerates-to-384-in-fourth-quarter-of-2024/\', \'content\': "Cybercrime crackdown: 306 arrested in Africa-wide operation\\n\\nA restored ancient museum palace showcases treasures from the Islamic world\\n\\nAdvertising\\n\\nBusiness\\n\\nNigeria\'s GDP growth accelerates to 3.84% in fourth quarter of 2024\\n\\nwith Other agencies\\n\\nNigeria\\n\\nIn the fourth quarter of 2024, Nigeria\'s economy experienced a notable acceleration, marking its most robust growth in three years, primarily fueled by the services sector, according to data released on Tuesday. [...] In the last quarter of 2024, Nigeria\'s average daily oil production stood at 1.54 million barrels, showing minimal variation from the previous year\'s figure of 1.56 million barrels, according to the latest data.\\n\\nThis stability in oil output reflects the ongoing challenges and dynamics within the sector.\\n\\nMeanwhile, the agricultural sector experienced a growth rate of 1.76%, indicating a modest but positive trend in food production and related activities. [...] Additionally, industrial output saw a more robust expansion of 2.00%, suggesting that manufacturing and other industrial activities are gaining momentum in the economy.\\n\\nLooking ahead, the International Monetary Fund projects that Nigeria\'s economy will grow by 3.2% this year.\\n\\nThis forecast highlights a hopeful outlook for the nation, driven by improvements in various sectors and a potential recovery from previous economic challenges.\\n\\nYou may also like", \'score\': 0.90985113}]', '#E2': "I'd be happy to help analyze economic data. Can you please provide me with the data you'd like me to analyze? Additionally, please let me know what type of analysis you're looking for (e.g. trend analysis, correlation analysis, regression analysis, etc.) and what specific economic indicators you're interested in (e.g. GDP, inflation rate, unemployment rate, etc.)?\n\nIf you don't have specific data in mind, I can suggest some common economic indicators that are often analyzed:\n\n1. GDP (Gross Domestic Product): measures the total value of goods and services produced within a country's borders.\n2. Inflation Rate: measures the rate of change in the general price level of goods and services in an economy.\n3. Unemployment Rate: measures the percentage of the labor force that is currently unemployed.\n4. Interest Rates: measures the rate at which banks and other financial institutions lend and borrow money.\n5. Exchange Rates: measures the value of one country's currency relative to another country's currency.\n6. Consumer Price Index (CPI): measures the average change in prices of a basket of goods and services consumed by households.\n7. Producer Price Index (PPI): measures the average change in prices of a basket of goods and services produced by businesses.\n\nLet me know if you have any specific data or questions, and I'll do my best to help you analyze it!", '#E3': 'Here are some movie ideas across various genres:\n\n**Action/Adventure**\n\n1. "The Last Hope": In a post-apocalyptic world, a group of survivors must navigate treacherous terrain to reach a rumored safe haven.\n2. "The Shadow Agency": A secret organization of spies and assassins must take down a rogue agent who\'s stolen a powerful technology.\n3. "The Lost City": An archaeologist discovers a hidden city deep in the jungle, but soon finds himself hunted by treasure hunters and rival expeditions.\n\n**Science Fiction**\n\n1.  ...
# ------------------------------------------------------------
# Current State: {'solve': {'result': 'Based on the plan and collected evidence, I will provide a movie script about Nigeria and its economic situation.\n\n**Title:** "The Last Hope"\n\n**Genre:** Action/Adventure\n\n**Plot:**\n\nIn a post-apocalyptic world, Nigeria\'s economy has collapsed, and the country is on the brink of chaos. A group of survivors, led by a young woman named Nneoma, must navigate treacherous terrain to reach a rumored safe haven.\n\nAs they journey through the ruins of Lagos, they encounter various challenges, including marauders, corrupt government officials, and rival factions vying for control. Along the way, they discover that the safe haven is not just a myth, but a real place where they can start anew.\n\nHowever, they soon realize that the safe haven is not as safe as they thought. The leader of the safe haven, a charismatic figure named Dr. Okoro, has his own agenda and is using the survivors for his own gain.\n\nNneoma and her team must use their skills and resources to take down Dr. Okoro and his followers, and find a way to rebuild Nigeria\'s economy and restore hope to its people.\n\n**Script:**\n\nFADE IN:\n\nEXT. LAGOS - DAY\n\nThe camera pans over the ruins of Lagos, showing the devastation caused by the economic collapse. We see Nneoma, a young woman with a determined look on her face, leading a group of survivors through the rubble.\n\nNNEOMA\n(to the group)\nWe\'re getting close. I can feel it.\n\nSuddenly, they hear gunfire and explosions in the distance.\n\nNNEOMA\n(to the group)\nStay close. We need to move quickly.\n\nCUT TO:\n\nINT. SAFE HAVEN - DAY\n\nThe group arrives at the safe haven, a heavily fortified compound surrounded by walls and guarded by armed men. Dr. Okoro, a charismatic figure with a warm smile, greets them.\n\nDR. OKORO\nWelcome, my friends. You\'re just in time. We\'re about to start a new chapter in Nigeria\'s history.\n\nNNEOMA\n(skeptical)\nWhat do you mean?\n\nDR. OKORO\n(smiling)\nWe\'re going to rebuild Nigeria\'s economy, and make it stronger than ever before.\n\nNNEOMA\n(doubtful)\nHow are you going to do that?\n\nDR. OKORO\n(confidently)\nI have a plan. And with your help, we can make it happen.\n\nCUT TO:\n\nEXT. SAFE HAVEN - DAY\n\nAs the group settles in, they begin to notice that something is off. The guards are overly aggressive, and the food is scarce. Nneoma becomes suspicious and decides to investigate.\n\nNNEOMA\n(to Dr. Okoro)\nI need to talk to you about something.\n\nDR. OKORO\n(surprised)\nWhat is it?\n\nNNEOMA\n(serious)\nI\'ve been noticing some strange things around here. The guards are aggressive, and the food is scarce. What\'s going on?\n\nDR. OKORO\n(smiling)\nOh, that? Just a few minor issues. We\'re working on them.\n\nNNEOMA\n(unconvinced)\nI don\'t believe you. You\'re using us for your own gain, aren\'t you?\n\nDR. OKORO\n(angrily)\nHow dare you! I\'m trying to rebuild Nigeria\'s economy, and you\'re questioning my motives?\n\nNNEOMA\n(firmly)\nI\'m not going to let you use us for your own gain. We\'re going to take you down.\n\nCUT TO:\n\nEXT. SAFE HAVEN - DAY\n\nNneoma and her team launch a surprise attack on Dr. Okoro and his followers. The battle is intense, with both sides suffering heavy losses.\n\nIn the end, Nneoma and her team emerge victorious, and Dr. Okoro is defeated.\n\nNNEOMA\n(to the group)\nWe did it. We took back our country.\n\nThe group cheers, and Nneoma looks out at the ruins of Lagos, knowing that there is still much work to be done.\n\nFADE TO BLACK.\n\n**Conclusion:**\n\n"The Last Hope" is a movie script about Nigeria and its economic situation. The story follows a group of survivors as they navigate the challenges of rebuilding their country after an economic collapse. Along the way, they encounter various obstacles, including corrupt government officials and rival factions vying for control. In the end, they must use their skills and resources to take down the leader of the safe haven and restore hope to  ...
# ------------------------------------------------------------
#
# Final Result:
# None

# %%
from IPython.display import Markdown, display

mermaid_code = app.get_graph().draw_mermaid()
display(Markdown(f"```mermaid\n{mermaid_code}\n```"))
# Out:
# ```mermaid
# ---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	plan(plan)
# 	tool(tool)
# 	solve(solve)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> plan;
# 	plan --> tool;
# 	solve --> __end__;
# 	tool -.-> plan;
# 	tool -.-> solve;
# 	tool -.-> __end__;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc
#
# ```
